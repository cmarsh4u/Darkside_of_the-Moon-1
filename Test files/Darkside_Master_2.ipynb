# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import csv
import json
import requests
import datetime as dt

# %%
# Import ems data from csv
ems_df = pd.read_csv("EMS_DATA.csv")
ems_df = ems_df.rename(columns={"GROUP_DATE":"Date"})
ems_df.head()
# Out:
#          Date  INCIDENT_DATETIME  INITIAL_SEVERITY_LEVEL_CODE
# 0  01/01/2016               4879                     4.139373
# 1  01/01/2017               4928                     4.196226
# 2  01/01/2018               4653                     4.137975
# 3  01/02/2016               3439                     4.165455
# 4  01/02/2017               3685                     4.181818

# %%
# Import moon data from csv
moon_df = pd.read_csv("Moon_Data.csv")
del moon_df["Unnamed: 0"]
moon_df.head()
# Out:
#          Date          Phase
# 0  01/02/2016   Last Quarter
# 1  01/10/2016       New Moon
# 2  01/16/2016  First Quarter
# 3  01/24/2016      Full Moon
# 4  02/01/2016   Last Quarter

# %%
# Change the date to a datetime object
moon_df['DATETIME']= pd.to_datetime(moon_df['Date'])
moon_df= moon_df.astype({'DATETIME': 'datetime64'})
moon_df['GROUP_DATE']= moon_df['DATETIME'].dt.strftime("%Y/%m/%d")
moon_df.head()
# Out:
#          Date          Phase   DATETIME  GROUP_DATE
# 0  01/02/2016   Last Quarter 2016-01-02  2016/01/02
# 1  01/10/2016       New Moon 2016-01-10  2016/01/10
# 2  01/16/2016  First Quarter 2016-01-16  2016/01/16
# 3  01/24/2016      Full Moon 2016-01-24  2016/01/24
# 4  02/01/2016   Last Quarter 2016-02-01  2016/02/01

# %%
# Merge tables
darkside = pd.merge(ems_df, moon_df, on="Date", how="left")

#Clean up table
del darkside["INCIDENT_DATETIME"]
darkside = darkside.rename(columns={"INITIAL_SEVERITY_LEVEL_CODE":"Initial Severity Level Code"})
darkside
# Out:
#             Date  Initial Severity Level Code          Phase   DATETIME  \
# 0     01/01/2016                     4.139373            NaN        NaT
# 1     01/01/2017                     4.196226            NaN        NaT
# 2     01/01/2018                     4.137975            NaN        NaT
# 3     01/02/2016                     4.165455   Last Quarter 2016-01-02
# 4     01/02/2017                     4.181818            NaN        NaT
# 5     01/02/2018                     4.166667      Full Moon 2018-01-02
# 6     01/03/2016                     4.230702            NaN        NaT
# 7     01/03/2017                     4.205486            NaN        NaT
# 8     01/03/2018                     4.228162            NaN        NaT
# 9     01/04/2016                     4.241705            NaN        NaT
# 10    01/04/2017                     4.290337            NaN        NaT
# 11    01/04/2018                     4.252000            NaN        NaT
# 12    01/05/2016                     4.215274            NaN        NaT
# 13    01/05/2017                     4.296184  First Quarter 2017-01-05
# 14    01/05/2018                     4.352350            NaN        NaT
# 15    01/06/2016                     4.296703            NaN        NaT
# 16    01/06/2017                     4.317305            NaN        NaT
# 17    01/06/2018                     4.264513            NaN        NaT
# 18    01/07/2016                     4.228897            NaN        NaT
# 19    01/07/2017                     4.334853            NaN        NaT
# 20    01/07/2018                     4.204203            NaN        NaT
# 21    01/08/2016                     4.248064            NaN        NaT
# 22    01/08/2017                     4.283985            NaN        NaT
# 23    01/08/2018                     4.264895   Last Quarter 2018-01-08
# 24    01/09/2016                     4.242762            NaN        NaT
# 25    01/09/2017                     4.256693            NaN        NaT
# 26    01/09/2018                     4.233449            NaN        NaT
# 27    01/10/2016                     4.181558       New Moon 2016-01-10
# 28    01/10/2017                     4.270472            NaN        NaT
# 29    01/10/2018                     4.259002            NaN        NaT
# ...          ...                          ...            ...        ...
# 1066  12/22/2016                     4.255024            NaN        NaT
# 1067  12/22/2017                     4.191596            NaN        NaT
# 1068  12/22/2018                     4.132536      Full Moon 2018-12-22
# 1069  12/23/2016                     4.182256            NaN        NaT
# 1070  12/23/2017                     4.233418            NaN        NaT
# 1071  12/23/2018                     4.168985            NaN        NaT
# 1072  12/24/2016                     4.200298            NaN        NaT
# 1073  12/24/2017                     4.194042            NaN        NaT
# 1074  12/24/2018                     4.179221            NaN        NaT
# 1075  12/25/2016                     4.193747            NaN        NaT
# 1076  12/25/2017                     4.179065            NaN        NaT
# 1077  12/25/2018                     4.188733            NaN        NaT
# 1078  12/26/2016                     4.210406            NaN        NaT
# 1079  12/26/2017                     4.256686  First Quarter 2017-12-26
# 1080  12/26/2018                     4.205846            NaN        NaT
# 1081  12/27/2016                     4.168946            NaN        NaT
# 1082  12/27/2017                     4.252028            NaN        NaT
# 1083  12/27/2018                     4.234715            NaN        NaT
# 1084  12/28/2016                     4.219463            NaN        NaT
# 1085  12/28/2017                     4.280041            NaN        NaT
# 1086  12/28/2018                     4.164786            NaN        NaT
# 1087  12/29/2016                     4.219691       New Moon 2016-12-29
# 1088  12/29/2017                     4.270257            NaN        NaT
# 1089  12/29/2018                     4.165036   Last Quarter 2018-12-29
# 1090  12/30/2016                     4.233190            NaN        NaT
# 1091  12/30/2017                     4.196469            NaN        NaT
# 1092  12/30/2018                     4.207718            NaN        NaT
# 1093  12/31/2016                     4.150090            NaN        NaT
# 1094  12/31/2017                     4.265399            NaN        NaT
# 1095  12/31/2018                     4.203839            NaN        NaT
#
#       GROUP_DATE
# 0            NaN
# 1            NaN
# 2            NaN
# 3     2016/01/02
# 4            NaN
# 5     2018/01/02
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13    2017/01/05
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23    2018/01/08
# 24           NaN
# 25           NaN
# 26           NaN
# 27    2016/01/10
# 28           NaN
# 29           NaN
# ...          ...
# 1066         NaN
# 1067         NaN
# 1068  2018/12/22
# 1069         NaN
# 1070         NaN
# 1071         NaN
# 1072         NaN
# 1073         NaN
# 1074         NaN
# 1075         NaN
# 1076         NaN
# 1077         NaN
# 1078         NaN
# 1079  2017/12/26
# 1080         NaN
# 1081         NaN
# 1082         NaN
# 1083         NaN
# 1084         NaN
# 1085         NaN
# 1086         NaN
# 1087  2016/12/29
# 1088         NaN
# 1089  2018/12/29
# 1090         NaN
# 1091         NaN
# 1092         NaN
# 1093         NaN
# 1094         NaN
# 1095         NaN
#
# [1096 rows x 5 columns]
